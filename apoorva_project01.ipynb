# %%
# Student Dataset Analysis (No file needed)

# Creating dataset directly
names = ["Apoorva", "Rahul", "Sneha", "Kiran", "Anjali"]
marks = [85, 78, 92, 66, 88]

# Calculations
average = sum(marks) / len(marks)
highest = max(marks)
lowest = min(marks)

# Display student data
print("Student Data:")
for i in range(len(names)):
    print(names[i], "-", marks[i])

print("\nAnalysis Result")
print("----------------------")
print("Average Marks:", average)
print("Highest Marks:", highest)
print("Lowest Marks:", lowest)
# Out:
# Student Data:
# Apoorva - 85
# Rahul - 78
# Sneha - 92
# Kiran - 66
# Anjali - 88
#
# Analysis Result
# ----------------------
# Average Marks: 81.8
# Highest Marks: 92
# Lowest Marks: 66
