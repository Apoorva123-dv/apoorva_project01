# %%
# Simple Movie Recommendation System

genre = input("Enter movie type (action/comedy/romance): ").lower()

if genre == "action":
    print("Recommended Movie: Avengers")
elif genre == "comedy":
    print("Recommended Movie: Mr. Bean")
elif genre == "romance":
    print("Recommended Movie: Titanic")
else:
    print("No recommendation available")
# Out:
# Enter movie type (action/comedy/romance): action
# Recommended Movie: Avengers
